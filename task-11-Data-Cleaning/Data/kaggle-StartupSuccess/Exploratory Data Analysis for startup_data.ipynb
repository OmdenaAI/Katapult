# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
from sklearn import impute
import numpy as np
pd.pandas.set_option('display.max_columns',None)

# %%
stupdata = pd.read_csv('startup_data.csv', index_col = 'id')

# %%
stupdata.head()
# Out:
#          Unnamed: 0 state_code   latitude   longitude zip_code           city  \
# id
# c:6669         1005         CA  42.358880  -71.056820    92101      San Diego
# c:16283         204         CA  37.238916 -121.973718    95032      Los Gatos
# c:65620        1001         CA  32.901049 -117.192656    92121      San Diego
# c:42668         738         CA  37.320309 -122.050040    95014      Cupertino
# c:65806        1002         CA  37.779281 -122.419236    94105  San Francisco
#
#                      Unnamed: 6               name  labels founded_at  \
# id
# c:6669                      NaN        Bandsintown       1   1/1/2007
# c:16283                     NaN          TriCipher       1   1/1/2000
# c:65620      San Diego CA 92121              Plixi       1  3/18/2009
# c:42668      Cupertino CA 95014  Solidcore Systems       1   1/1/2002
# c:65806  San Francisco CA 94105     Inhale Digital       0   8/1/2010
#
# ...

# %%
stupdata.tail()
# Out:
#          Unnamed: 0 state_code   latitude   longitude zip_code           city  \
# id
# c:21343         352         CA  37.740594 -122.376471    94107  San Francisco
# c:41747         721         MA  42.504817  -71.195611     1803     Burlington
# c:31549         557         CA  37.408261 -122.015920    94089      Sunnyvale
# c:33198         589         CA  37.556732 -122.288378    94404  San Francisco
# c:26702         462         CA  37.386778 -121.966277    95054    Santa Clara
#
#                    Unnamed: 6                  name  labels founded_at  \
# id
# c:21343                   NaN               CoTweet       1   1/1/2009
# c:41747    Burlington MA 1803    Reef Point Systems       0   1/1/1998
# c:31549                   NaN       Paracor Medical       0   1/1/1999
# c:33198                   NaN               Causata       1   1/1/2009
# c:26702  Santa Clara CA 95054  Asempra Technologies       1   1/1/2003
#
# ...

# %%
stupdata.describe()
# Out:
#         Unnamed: 0    latitude   longitude      labels  \
# count   923.000000  923.000000  923.000000  923.000000
# mean    572.297941   38.517442 -103.539212    0.646804
# std     333.585431    3.741497   22.394167    0.478222
# min       1.000000   25.752358 -122.756956    0.000000
# 25%     283.500000   37.388869 -122.198732    0.000000
# 50%     577.000000   37.779281 -118.374037    1.000000
# 75%     866.500000   40.730646  -77.214731    1.000000
# max    1153.000000   59.335232   18.057121    1.000000
#
#        age_first_funding_year  age_last_funding_year  \
# count              923.000000             923.000000
# mean                 2.235630               3.931456
# std                  2.510449               2.967910
# min                 -9.046600              -9.046600
# 25%                  0.576700               1.669850
# 50%                  1.446600               3.528800
# 75%                  3.575350               5.560250
# ...

# %%
stupdata.columns
# Out:
# Index(['Unnamed: 0', 'state_code', 'latitude', 'longitude', 'zip_code', 'city',
#        'Unnamed: 6', 'name', 'labels', 'founded_at', 'closed_at',
#        'first_funding_at', 'last_funding_at', 'age_first_funding_year',
#        'age_last_funding_year', 'age_first_milestone_year',
#        'age_last_milestone_year', 'relationships', 'funding_rounds',
#        'funding_total_usd', 'milestones', 'state_code.1', 'is_CA', 'is_NY',
#        'is_MA', 'is_TX', 'is_otherstate', 'category_code', 'is_software',
#        'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
#        'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
#        'is_othercategory', 'object_id', 'has_VC', 'has_angel', 'has_roundA',
#        'has_roundB', 'has_roundC', 'has_roundD', 'avg_participants',
#        'is_top500', 'status'],
#       dtype='object')

# %%
stupdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 923 entries, c:6669 to c:26702
# Data columns (total 48 columns):
# Unnamed: 0                  923 non-null int64
# state_code                  923 non-null object
# latitude                    923 non-null float64
# longitude                   923 non-null float64
# zip_code                    923 non-null object
# city                        923 non-null object
# Unnamed: 6                  430 non-null object
# name                        923 non-null object
# labels                      923 non-null int64
# founded_at                  923 non-null object
# closed_at                   335 non-null object
# first_funding_at            923 non-null object
# last_funding_at             923 non-null object
# age_first_funding_year      923 non-null float64
# age_last_funding_year       923 non-null float64
# age_first_milestone_year    771 non-null float64
# age_last_milestone_year     771 non-null float64
# ...

# %%
stupdata.shape
# Out:
# (923, 48)

# %% [markdown]
# ## Number of missing values in the features in the dataset

# %%
missing = stupdata.isnull().sum()
missing.sort_values(ascending=False)
# Out:
# closed_at                   588
# Unnamed: 6                  493
# age_last_milestone_year     152
# age_first_milestone_year    152
# state_code.1                  1
# status                        0
# last_funding_at               0
# milestones                    0
# funding_total_usd             0
# funding_rounds                0
# relationships                 0
# age_last_funding_year         0
# age_first_funding_year        0
# first_funding_at              0
# is_top500                     0
# founded_at                    0
# labels                        0
# name                          0
# city                          0
# zip_code                      0
# longitude                     0
# latitude                      0
# state_code                    0
# is_CA                         0
# is_NY                         0
# is_MA                         0
# is_consulting                 0
# avg_participants              0
# has_roundD                    0
# ...

# %%
#missing = missing[missing > 0]
#missing.sort_values(inplace = True)

# %%
#fig = plt.figure(figsize = (10,10))
#sns.set(style = 'whitegrid')
#ax = sns.barplot(x = missing.index.tolist(), y = missing, palette = 'hot_r')
#ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
#plt.show()

# %% [markdown]
# Checking the percentage of nan values present in each feature

# %%
# Finding the percentage of missing values

print("Percentage of missing values in 'closed_at' column: % {:.2f}". format((stupdata.closed_at.isnull().sum())/len(stupdata)*100))
print("Percentage of missing values in 'Unnamed: 6' column: % {:.2f}". format((stupdata["Unnamed: 6"].isnull().sum())/len(stupdata)*100))
print("Percentage of missing values in 'age_last_milestone_year' column  : % {:.2f}". format((stupdata.age_last_milestone_year.isnull().sum())/len(stupdata)*100))
print("percentage of missing values in 'age_first_milestone_year' column : % {:.2f}". format((stupdata.age_first_milestone_year.isnull().sum())/len(stupdata)*100))
# Out:
# Percentage of missing values in 'closed_at' column: % 63.71
# Percentage of missing values in 'Unnamed: 6' column: % 53.41
# Percentage of missing values in 'age_last_milestone_year' column  : % 16.47
# percentage of missing values in 'age_first_milestone_year' column : % 16.47

# %% [markdown]
# Finding relationship between missing values and Startup Success Prediction

# %%
for feature in features_with_na:
    data = stupdata.copy()
    
    data[feature] = np.where(data[feature].isnull(), 1, 0)
    
    data.groupby(feature)['is_top500'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %%
print("Id of Houses {}".format(len(stupdata.object_id)))
# Out:
# Id of Houses 923

# %% [markdown]
# ## Numerical Variables

# %%
stupdata.dtypes
# Out:
# Unnamed: 0                    int64
# state_code                   object
# latitude                    float64
# longitude                   float64
# zip_code                     object
# city                         object
# Unnamed: 6                   object
# name                         object
# labels                        int64
# founded_at                   object
# closed_at                    object
# first_funding_at             object
# last_funding_at              object
# age_first_funding_year      float64
# age_last_funding_year       float64
# age_first_milestone_year    float64
# age_last_milestone_year     float64
# relationships                 int64
# funding_rounds                int64
# funding_total_usd             int64
# milestones                    int64
# state_code.1                 object
# is_CA                         int64
# is_NY                         int64
# is_MA                         int64
# is_TX                         int64
# ...

# %%
# list of numerical variables
numerical_features = [feature for feature in stupdata.columns if stupdata[feature].dtypes != 'O']

print('Number of numerical variables: ', len(numerical_features))

# visualise the numerical variables
stupdata[numerical_features].head()
# Out:
# Number of numerical variables:  35
#          Unnamed: 0   latitude   longitude  labels  age_first_funding_year  \
# id
# c:6669         1005  42.358880  -71.056820       1                  2.2493
# c:16283         204  37.238916 -121.973718       1                  5.1260
# c:65620        1001  32.901049 -117.192656       1                  1.0329
# c:42668         738  37.320309 -122.050040       1                  3.1315
# c:65806        1002  37.779281 -122.419236       0                  0.0000
#
#          age_last_funding_year  age_first_milestone_year  \
# id
# c:6669                  3.0027                    4.6685
# c:16283                 9.9973                    7.0055
# c:65620                 1.0329                    1.4575
# c:42668                 5.3151                    6.0027
# c:65806                 1.6685                    0.0384
#
#          age_last_milestone_year  relationships  funding_rounds  \
# id
# ...

# %%
# Types of numerical variables - discrete & continuous variables

discrete_feature=[feature for feature in numerical_features if len(stupdata[feature].unique())<25]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 25

# %%
discrete_feature
# Out:
# ['labels',
#  'funding_rounds',
#  'milestones',
#  'is_CA',
#  'is_NY',
#  'is_MA',
#  'is_TX',
#  'is_otherstate',
#  'is_software',
#  'is_web',
#  'is_mobile',
#  'is_enterprise',
#  'is_advertising',
#  'is_gamesvideo',
#  'is_ecommerce',
#  'is_biotech',
#  'is_consulting',
#  'is_othercategory',
#  'has_VC',
#  'has_angel',
#  'has_roundA',
#  'has_roundB',
#  'has_roundC',
#  'has_roundD',
#  'is_top500']

# %%
stupdata[discrete_feature].head()
# Out:
#          labels  funding_rounds  milestones  is_CA  is_NY  is_MA  is_TX  \
# id
# c:6669        1               3           3      1      0      0      0
# c:16283       1               4           1      1      0      0      0
# c:65620       1               1           2      1      0      0      0
# c:42668       1               3           1      1      0      0      0
# c:65806       0               2           1      1      0      0      0
#
#          is_otherstate  is_software  is_web  is_mobile  is_enterprise  \
# id
# c:6669               0            0       0          0              0
# c:16283              0            0       0          0              1
# c:65620              0            0       1          0              0
# c:42668              0            1       0          0              0
# c:65806              0            0       0          0              0
#
#          is_advertising  is_gamesvideo  is_ecommerce  is_biotech  \
# id
# ...

# %%
## Realtionship between discrete features and 'has_roundC' funding as a measure of success of a startup

for feature in discrete_feature:
    data=stupdata.copy()
    data.groupby(feature)['has_roundC'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('has_roundC')
    plt.title(feature)
    plt.show()

# %% [markdown]
# #### Continuous Variable

# %%
continuous_feature=[feature for feature in numerical_features if feature not in discrete_feature+['id']]
print("Continuous feature Count {}".format(len(continuous_feature)))
# Out:
# Continuous feature Count 10

# %%
continuous_feature
# Out:
# ['Unnamed: 0',
#  'latitude',
#  'longitude',
#  'age_first_funding_year',
#  'age_last_funding_year',
#  'age_first_milestone_year',
#  'age_last_milestone_year',
#  'relationships',
#  'funding_total_usd',
#  'avg_participants']

# %%
## Analyzing the continuous values by creating histograms to understand the distribution

for feature in continuous_feature:
    data=stupdata.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()
