# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %% [markdown]
# ### angelco

# %%
data=pd.read_csv("../Data/angelco/angelco_companies.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (379, 10)
#
# unique elements in Features
#
# Company         379
# Link            379
# Pitch           271
# Joined           69
# Location         73
# Market          185
# Website         362
# Employees         7
# Stage             9
# Total_raised    193
# dtype: int64
#
# Company         100.000000
# Link            100.000000
# Pitch            71.503958
# Joined          100.000000
# Location        100.000000
# Market          100.000000
# Website          97.889182
# Employees        93.139842
# Stage            90.501319
# Total_raised    100.000000
# dtype: float64

# %%
data=pd.read_csv("../Data/angelco/uStartups.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (1044, 8)
#
# unique elements in Features
#
# name            1041
# email           1039
# product_desc     993
# high_concept     986
# location          25
# market1          146
# market2          227
# market3          322
# dtype: int64
#
# name            100.000000
# email           100.000000
# product_desc     95.114943
# high_concept     94.444444
# location        100.000000
# market1          96.934866
# market2          91.570881
# market3          84.099617
# dtype: float64

# %% [markdown]
# ### AngelList

# %%
data=pd.read_csv("../Data/AngelList/808 companies_2018.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (808, 8)
#
# unique elements in Features
#
# name         556
# desc         513
# website      557
# location      90
# employees      7
# raised       305
# angel_url    546
# angel_id     557
# dtype: int64
#
# name         100.000000
# desc         100.000000
# website      100.000000
# location     100.000000
# employees     97.896040
# raised       100.000000
# angel_url     99.381188
# angel_id     100.000000
# dtype: float64

# %% [markdown]
# ### app.dealroom.co

# %%
# data=pd.read_excel("../Data/app.dealroom.co/list_rounds.xlsx")
# read_file = pd.read_excel ("../Data/app.dealroom.co/list_rounds.xlsx")
# read_file.to_csv ("../Data/app.dealroom.co/list_rounds.csv", index = None,header=True)

# data = pd.DataFrame(pd.read_csv("../Data/app.dealroom.co/list_rounds.csv"))
  
# print("Shape of Dataset")
# print(data.shape)
# print()

# print(data.count()/data.isna().count()*100)

# %% [markdown]
# ### autopsy_io(failed_companies)

# %%
data=pd.read_csv("../Data/autopsy_io/failed_companies_autopsyio_dataset.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (162, 9)
#
# unique elements in Features
#
# Date_of_Failure        85
# Startup               162
# Idea                  162
# Reason_for_Failure    162
# Full_Story            161
# Founder               147
# Startup_link          124
# Full_story_link       159
# Founder_link          149
# dtype: int64
#
# Date_of_Failure       100.000000
# Startup               100.000000
# Idea                  100.000000
# Reason_for_Failure    100.000000
# Full_Story            100.000000
# Founder                91.358025
# Startup_link           77.160494
# Full_story_link        98.148148
# Founder_link           91.975309
# dtype: float64

# %% [markdown]
# ### crunchbase-data

# %%
data=pd.read_csv("../Data/crunchbase-data/acquisitions.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (18968, 18)
#
# unique elements in Features
#
# company_permalink         18521
# company_name              18503
# company_category_list      5930
# company_country_code         86
# company_state_code          243
# company_region              649
# company_city               2407
# acquirer_permalink         9489
# acquirer_name              9475
# acquirer_category_list     3834
# acquirer_country_code        80
# acquirer_state_code         201
# acquirer_region             549
# acquirer_city              1759
# acquired_at                3950
# acquired_month              299
# price_amount               1529
# price_currency_code          18
# dtype: int64
#
# company_permalink         100.000000
# company_name              100.000000
# company_category_list      73.729439
# company_country_code       75.390131
# company_state_code         73.913960
# company_region             74.114298
# company_city               74.114298
# ...

# %%
data=pd.read_csv("../Data/crunchbase-data/additions.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (2213, 4)
#
# unique elements in Features
#
# content       21
# month_str    449
# year_str      50
# value        755
# dtype: int64
#
# content      100.0
# month_str    100.0
# year_str     100.0
# value        100.0
# dtype: float64

# %%
data=pd.read_csv("../Data/crunchbase-data/companies.csv")

print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (66368, 14)
#
# unique elements in Features
#
# permalink            66368
# name                 66102
# homepage_url         61191
# category_list        27296
# funding_total_usd    18896
# status                   4
# country_code           137
# state_code             311
# region                1092
# city                  5111
# funding_rounds          19
# founded_at            3978
# first_funding_at      4817
# last_funding_at       4518
# dtype: int64
#
# permalink            100.000000
# name                  99.998493
# homepage_url          92.378857
# category_list         95.256750
# funding_total_usd    100.000000
# status               100.000000
# country_code          89.516032
# state_code            87.121806
# region                87.900796
# city                  87.903809
# funding_rounds       100.000000
# founded_at            77.065755
# first_funding_at      99.963838
# last_funding_at      100.000000
# dtype: float64

# %%
data=pd.read_csv("../Data/crunchbase-data/investments.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (168647, 18)
#
# unique elements in Features
#
# company_permalink          44739
# company_name               44578
# company_category_list      19453
# company_country_code         125
# company_state_code           297
# company_region               983
# company_city                3637
# investor_permalink         30732
# investor_name              30189
# investor_country_code         98
# investor_state_code          208
# investor_region              622
# investor_city               1762
# funding_round_permalink    71570
# funding_round_type            14
# funding_round_code             8
# funded_at                   4839
# raised_amount_usd          11079
# dtype: int64
#
# company_permalink          100.000000
# company_name                99.999407
# company_category_list       97.846389
# company_country_code        93.761526
# company_state_code          92.036028
# company_region              92.596963
# company_city                92.598149
# ...

# %%
data=pd.read_csv("../Data/crunchbase-data/rounds.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (114949, 12)
#
# unique elements in Features
#
# company_permalink           66368
# company_name                66102
# company_category_list       27296
# company_country_code          137
# company_state_code            311
# company_region               1092
# company_city                 5111
# funding_round_permalink    114949
# funding_round_type             14
# funding_round_code              8
# funded_at                    5033
# raised_amount_usd           22095
# dtype: int64
#
# company_permalink          100.000000
# company_name                99.999130
# company_category_list       97.033467
# company_country_code        92.450565
# company_state_code          90.477516
# company_region              91.155208
# company_city                91.157818
# funding_round_permalink    100.000000
# funding_round_type         100.000000
# funding_round_code          27.090275
# funded_at                  100.000000
# raised_amount_usd           82.609679
# ...

# %% [markdown]
# ### crunchbase-subscription-data

# %%
data=pd.read_csv("../Data/crunchbase-subscription-data/companies-11-2-2018.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (1000, 6)
#
# unique elements in Features
#
# Organization Name        1000
# Organization Name URL    1000
# Categories                982
# Headquarters Location     242
# Description              1000
# CB Rank (Company)         759
# dtype: int64
#
# Organization Name        100.0
# Organization Name URL    100.0
# Categories               100.0
# Headquarters Location     99.9
# Description              100.0
# CB Rank (Company)        100.0
# dtype: float64

# %%
data=pd.read_csv("../Data/crunchbase-subscription-data/companies-11-2-2018_more_columns.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (1000, 9)
#
# unique elements in Features
#
# Organization Name         1000
# Organization Name URL     1000
# Categories                 981
# Headquarters Location      243
# Description               1000
# CB Rank (Company)         1000
# Operating Status             2
# Founded Date               390
# Founded Date Precision       3
# dtype: int64
#
# Organization Name         100.0
# Organization Name URL     100.0
# Categories                100.0
# Headquarters Location      99.8
# Description               100.0
# CB Rank (Company)         100.0
# Operating Status          100.0
# Founded Date               99.0
# Founded Date Precision     99.0
# dtype: float64

# %% [markdown]
# ### enigma_dataset

# %%
data=pd.read_csv("../Data/enigma_dataset/enigma_dataset.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (22988, 51)
#
# unique elements in Features
#
# sec_file_number                                      22624
# irs_number                                           14278
# filed_as_of_date                                       210
# entity_name                                          20929
# issuer_name                                          20934
# primary_issuer_address1                              15157
# primary_issuer_address2                               3363
# primary_issuer_city                                   2789
# primary_issuer_state_or_country                        126
# primary_issuer_state_or_country_description            125
# primary_issuer_zipcode                                4753
# primary_issuer_phone                                 15282
# primary_issuer_previous_name_list                        0
# primary_issuer_entity_type                               6
# primary_issuer_inc_yet_to_be_true                        1
# ...

# %% [markdown]
# ### EU-Startup

# %%
data=pd.read_csv("../Data/EU-Startup/eu_startup_data.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (9595, 9)
#
# unique elements in Features
#
# business_name           9433
# country                   27
# business_description    9571
# based_in                1678
# tags                    9209
# founded                   18
# total_funding              9
# website                 9491
# articles                4112
# dtype: int64
#
# business_name           100.000000
# country                 100.000000
# business_description     99.874935
# based_in                100.000000
# tags                     98.436686
# founded                 100.000000
# total_funding            41.146430
# website                 100.000000
# articles                 50.724336
# dtype: float64

# %% [markdown]
# ### failory_startup_cemetery_data

# %%
data=pd.read_csv("../Data/failory_startup_cemetery_data/failory_cemetery_failedstartups.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (125, 16)
#
# unique elements in Features
#
# failed_startup          125
# short_description       125
# category                 15
# country                  19
# year_start               21
# year_closed              16
# outcome                   4
# cause                    17
# num_founders              6
# name_founders           122
# num_employees             9
# num_funding_rounds       12
# total_funding_amount     95
# num_investors            27
# full_description        125
# full_failure_cause      125
# dtype: int64
#
# failed_startup          100.0
# short_description       100.0
# category                100.0
# country                 100.0
# year_start              100.0
# year_closed             100.0
# outcome                 100.0
# cause                   100.0
# num_founders            100.0
# name_founders           100.0
# num_employees           100.0
# num_funding_rounds      100.0
# total_funding_amount    100.0
# ...

# %% [markdown]
# ### kaggle-AngelList

# %%
data=pd.read_csv("../Data/kaggle-AngelList/AngelList_Data_AI_Startups_v2.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (497, 16)
#
# unique elements in Features
#
# Name             497
# Profile URL      497
# Signal             5
# Location         168
# Market           199
# Website          496
# Employees          5
# Stage              5
# Total Raised     191
# Joining_Month     12
# Joining_Year       9
# latitude         165
# longitude        165
# date_today         1
# Age                9
# Country           52
# dtype: int64
#
# Name             100.000000
# Profile URL      100.000000
# Signal           100.000000
# Location          96.780684
# Market            99.195171
# Website           99.798793
# Employees         96.378270
# Stage             55.130785
# Total Raised      57.344064
# Joining_Month    100.000000
# Joining_Year     100.000000
# latitude          99.798793
# longitude         99.798793
# date_today       100.000000
# Age              100.000000
# Country          100.000000
# dtype: float64

# %%
data=pd.read_csv("../Data/kaggle-AngelList/AngelList_Startups.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (497, 13)
#
# unique elements in Features
#
# Name             497
# Profile URL      497
# Signal             5
# Location         168
# Market           199
# Website          496
# Employees          5
# Stage              5
# Total Raised     191
# Joining_Month     12
# Joining_Year       9
# latitude         165
# longitude        165
# dtype: int64
#
# Name             100.000000
# Profile URL      100.000000
# Signal           100.000000
# Location          96.780684
# Market            99.195171
# Website           99.798793
# Employees         96.378270
# Stage             55.130785
# Total Raised      57.344064
# Joining_Month    100.000000
# Joining_Year     100.000000
# latitude          99.798793
# longitude         99.798793
# dtype: float64

# %% [markdown]
# ### kaggle-Indian Unicorns

# %%
data=pd.read_csv("../Data/kaggle-Indian Unicorns/Indian_Unicorns.csv",encoding= 'ISO-8859-1')
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (34, 6)
#
# unique elements in Features
#
# Index        34
# Company      34
# Sector       15
# Valuation    20
# Entry         9
# Location      5
# dtype: int64
#
# Index        100.0
# Company      100.0
# Sector       100.0
# Valuation    100.0
# Entry        100.0
# Location     100.0
# dtype: float64

# %%
data=pd.read_csv("../Data/kaggle-Indian Unicorns/fundingdata.csv",encoding= 'ISO-8859-1')

print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (221, 8)
#
# unique elements in Features
#
# Start Date                      221
# End Date                        221
# Total Funding Amount(in USD)    215
# HF-Startup name                 158
# Highest Funding                 117
# Total Deals                      26
# Undisclosed Deals                16
# Year                              5
# dtype: int64
#
# Start Date                      100.0
# End Date                        100.0
# Total Funding Amount(in USD)    100.0
# HF-Startup name                 100.0
# Highest Funding                 100.0
# Total Deals                     100.0
# Undisclosed Deals               100.0
# Year                            100.0
# dtype: float64

# %% [markdown]
# ### kaggle-IndianStartup

# %%
data=pd.read_csv("../Data/kaggle-IndianStartup/startup_funding.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (3044, 10)
#
# unique elements in Features
#
# Sr No                3044
# Date dd/mm/yyyy      1035
# Startup Name         2459
# Industry Vertical     821
# SubVertical          1942
# City  Location        112
# Investors Name       2412
# InvestmentnType        55
# Amount in USD         471
# Remarks                72
# dtype: int64
#
# Sr No                100.000000
# Date dd/mm/yyyy      100.000000
# Startup Name         100.000000
# Industry Vertical     94.382392
# SubVertical           69.250986
# City  Location        94.086728
# Investors Name        99.211564
# InvestmentnType       99.868594
# Amount in USD         68.462549
# Remarks               13.764783
# dtype: float64

# %% [markdown]
# ### kaggle-PakistanStartups

# %%
# data=pd.read_csv("../Data/kaggle-PakistanStartups/FundedStartupsPakistan.xlsx")

# print("Shape of Dataset")
# print(data.shape)
# print()
# print(data.count()/data.isna().count()*100)

# %% [markdown]
# ### kaggle-SanFrancisco Startups = angelco(uStartups)

# %%
# data=pd.read_csv("../Data/kaggle-SanFrancisco Startups/")

# print("Shape of Dataset")
# print(data.shape)
# print()
# print(data.count()/data.isna().count()*100)

# %% [markdown]
# ### kaggle-startup-founders-valuation

# %%
data=pd.read_csv("../Data/kaggle-startup-founders-valuation/startup_founder_chars.csv",encoding= 'ISO-8859-1')

print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (574, 20)
#
# unique elements in Features
#
# Full Name                                      573
# Primary Company                                568
# Previous startups?                               9
# Consulting before start-up                       2
# Standardized University                        233
# Standardized Major                              30
# Degree Type                                     10
# Standardized Graduate Institution               92
# Standardized Graduate Studies                   28
# Graduate Diploma                                14
# Ever served as TA/Teacher/Professor/Mentor?      2
# Years of Employment                             28
# Worked as product manager/director/head/VP?      2
# Worked at Google?                                2
# Worked at Microsoft?                             2
# Worked in Sales?                                 2
# Stanford or Berkeley                             2
# ...

# %%
data=pd.read_csv("../Data/kaggle-startup-founders-valuation/startup_valuations.csv",encoding= 'ISO-8859-1')

print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (1469, 6)
#
# unique elements in Features
#
# Full Name             1216
# Primary Company       1201
# Seed Valuation         139
# A Valuation            300
# B Valuation            295
# Valuation Increase     315
# dtype: int64
#
# Full Name             100.0
# Primary Company       100.0
# Seed Valuation        100.0
# A Valuation           100.0
# B Valuation           100.0
# Valuation Increase    100.0
# dtype: float64

# %% [markdown]
# ### kaggle-StartupSuccess

# %%
data=pd.read_csv("../Data/kaggle-StartupSuccess/startup data.csv")

print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (923, 49)
#
# unique elements in Features
#
# Unnamed: 0                  923
# state_code                   35
# latitude                    652
# longitude                   651
# zip_code                    382
# id                          922
# city                        221
# Unnamed: 6                  252
# name                        922
# labels                        2
# founded_at                  217
# closed_at                   202
# first_funding_at            585
# last_funding_at             680
# age_first_funding_year      634
# age_last_funding_year       756
# age_first_milestone_year    471
# age_last_milestone_year     585
# relationships                41
# funding_rounds                9
# funding_total_usd           505
# milestones                    8
# state_code.1                 35
# is_CA                         2
# is_NY                         2
# is_MA                         2
# is_TX                         2
# ...

# %% [markdown]
# ### SeedStars

# %%
data=pd.read_csv("../Data/SeedStars/Seedstars_cleaned.csv")

print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (4255, 70)
#
# unique elements in Features
#
# company_id                                      4255
# event_name                                       214
# country                                          113
# industry                                          39
# business_stage                                     8
#                                                 ...
# amount_to_rise                                   479
# Funding before Seedstars - Split 1 - Split 1     455
# Funding after event from 3rd party               238
# Total Funding                                    636
# is_new_data                                        2
# Length: 70, dtype: int64
#
# company_id                                      100.000000
# event_name                                       99.576968
# country                                          99.694477
# industry                                         97.132785
# ...

# %% [markdown]
# ### start_up_io

# %%
data=pd.read_csv("../Data/start_up_io/data_from_startup_io.csv")
print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (639, 20)
#
# unique elements in Features
#
# market               470
# products              45
# launch_stage           7
# activity_level         5
# activity_verified    422
# pageviews            279
# team_member           11
# founded_by           525
# revenue_stage          6
# revenue_through      177
# twitter_followers    315
# percentile             2
# amount_raised         47
# company_website      628
# description          628
# name                 630
# founded              411
# place                210
# crunchbase_link      485
# ranking              247
# dtype: int64
#
# market               100.000000
# products              99.843505
# launch_stage         100.000000
# activity_level       100.000000
# activity_verified    100.000000
# pageviews            100.000000
# team_member          100.000000
# founded_by            85.446009
# revenue_stage        100.000000
# revenue_through      100.000000
# twitter_followers    100.000000
# ...

# %% [markdown]
# ### trak India startup

# %%
data=pd.read_csv("../Data/trak India startup/trak_india_startups.csv")

print("Shape of Dataset")
print(data.shape)
print()
print("unique elements in Features")
print()
print(data.nunique())
print()
print(data.count()/data.isna().count()*100)
x=data.count()/data.isna().count()*100
plt.hist(x)
plt.ylabel("Features of Dataset")
plt.xlabel("Dataset Present")
plt.show()
# Out:
# Shape of Dataset
# (3499, 10)
#
# unique elements in Features
#
# Unnamed: 0            3499
# Sr. No.                105
# Date (dd/mm/yyyy)     1130
# Startup Name          2575
# Industry/ Vertical    1016
# Sub-Vertical          2131
# City / Location        823
# Investors’ Name       1867
# Investment Type        237
# Amount (in USD)        540
# dtype: int64
#
# Unnamed: 0            100.000000
# Sr. No.                99.456988
# Date (dd/mm/yyyy)      98.856816
# Startup Name           98.399543
# Industry/ Vertical     98.399543
# Sub-Vertical           98.313804
# City / Location        96.913404
# Investors’ Name        94.341240
# Investment Type        86.510432
# Amount (in USD)        60.960274
# dtype: float64

# %%
# data=pd.read_csv("../Data/trak India startup/trak_india_startup01.csv")

# print("Shape of Dataset")
# print(data.shape)
# print()
# print(data.count()/data.isna().count()*100)

# %% [markdown]
# ### Linkedin education info of EM exited companies (SHARED)

# %%
# data=pd.read_excel("../Data/Linkedin education info of EM exited companies (SHARED).xlsx")

# print("Shape of Dataset")
# print(data.shape)
# print()
# print(data.count()/data.isna().count()*100)

# %% [markdown]
# ### scrapped_startups

# %%
# data=pd.read_excel("../Data/scrapped_startups.csv")

# print("Shape of Dataset")
# print(data.shape)
# print()
# print(data.count()/data.isna().count()*100)
